# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt

# %%
invA = pd.read_csv("./output/invA.csv",header=None)
res = pd.read_csv("./output/res.csv",header=None)

# %%
ana = pd.Series([0,15/32, 7/8, 39/32, 3/2])

# %%
x = np.linspace(0,1,len(res))
plt.plot(x, res,'*')
x = np.linspace(0,1,len(ana))
plt.plot(x,ana,'+-')

# %%
x = np.linspace(0,1,len(res))
plt.plot(x, res,'*')

# %%
res
# Out:
#           0
# 0   0.00000
# 1   0.02015
# 2   0.04020
# 3   0.06015
# 4   0.07999
# ..      ...
# 95  1.45900
# 96  1.46900
# 97  1.48000
# 98  1.49000
# 99  1.50000
#
# [100 rows x 1 columns]
